# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np

# %%
fig = plt.figure()

# %%
ax = plt.axes()

# %%
np.linspace(0,10,20)
# Out:
# array([  0.        ,   0.52631579,   1.05263158,   1.57894737,
#          2.10526316,   2.63157895,   3.15789474,   3.68421053,
#          4.21052632,   4.73684211,   5.26315789,   5.78947368,
#          6.31578947,   6.84210526,   7.36842105,   7.89473684,
#          8.42105263,   8.94736842,   9.47368421,  10.        ])

# %%
fig = plt.figure() # create a fig object
ax = plt.axes() # create axes
x = np.linspace(0,10,1000) # generate points
ax.plot(x, x) # plot sin curve
ax.plot(x, np.cos(x),) # plot cos curve

# %% [markdown]
# ### Line Colors & Styles

# %%
plt.plot(x, np.sin(x), color='red')

# %%
plt.plot(x, np.sin(x), color='#91487B')

# %%
plt.plot(x, np.sin(x), color='#91487B', linestyle='-.')

# %%
plt.plot(x, np.sin(x),'-.r')

# %% [markdown]
# ### Axes Limits

# %%
plt.plot(x, np.sin(x))
plt.xlim(-5,10)
plt.ylim(0,20)
# Out:
# (0, 20)

# %%
plt.plot(x, np.sin(x))
plt.axis('equal')
plt.title('My matplot graph')
plt.xlabel('x')
plt.ylabel('sin(x)')

# %%
plt.plot( x, np.sin(x), label='sin(x)')
plt.plot( x, np.cos(x), label='cos(x)')
#plt.axis('equal')
# plotting the legend
plt.legend()
