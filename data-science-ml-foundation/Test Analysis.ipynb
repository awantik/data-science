# %%
import pandas as pd

# %%
wp = pd.read_csv(r'C:\Users\ZekeLabs\Downloads\Working_Population_according_to_2011_Census.csv')

# %%
wp.head()
# Out:
#   India/State/Union Territory  Total Population_Persons  Main Workers_Persons  \
# 0                       India                1210569573             362446420
# 1              Andhra Pradesh                  84580777              33037378
# 2           Arunachal Pradesh                   1383727                478721
# 3                       Assam                  31205576               8687123
# 4                       Bihar                 104099452              21359611
#
#    Percentage of main Workers to total Population_2001_Persons  \
# 0                                              30.43
# 1                                              38.11
# 2                                              37.80
# 3                                              26.69
# 4                                              25.37
#
#    Percentage of main Workers to total Population_2011_Persons  \
# 0                                              29.94
# ...

# %%
from bokeh.charts import Bar, output_file, show #use output_notebook to visualize it in notebook
# prepare data (dummy data)
data = {"y": [1, 2, 3, 4, 5]}
# Output to Line.HTML
output_file("lines1.html", title="line plot example") #put output_notebook() for notebook
# create a new line chat with a title and axis labels
p = Bar(data, title="Line Chart Example", xlabel='x', ylabel='values', width=400, height=400)
# show the results
show(p)

# %%
import matplotlib.pyplot as plt
fig, ax = plt.subplots( nrows=1, ncols=1 )  # create figure & 1 axis
ax.plot([0,1,2], [10,20,3])
fig.savefig('to.png')   # save the figure to file
plt.close(fig)    # close the figure
