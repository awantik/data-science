# %% [markdown]
# ## Bringing together NLES data
#
# Source: http://mhrd.gov.in/statist?field_statistics_category_tid=30

# %%
import pandas as pd
table_1 = pd.read_excel(r'data/NLES_table1_xlsx.xlsx')

# %%
table_1.head()
# Out:
#       Table1-:Population Census- 2001 & 2011 - (in Crore) Unnamed: 1  \
# 0                                                NaN             NaN
# 1                                                NaN           Total
# 2                                                NaN            Male
# 3                                                NaN          Female
# 4                                                NaN             NaN
#
#   Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7
# 0        NaN       2001        NaN       2011        NaN        NaN
# 1        NaN      102.8        NaN     121.02        NaN        NaN
# 2        NaN       53.2        NaN      62.37        NaN        NaN
# 3        NaN      49.65        NaN      58.65        NaN        NaN
# 4        NaN        NaN        NaN        NaN        NaN        NaN

# %%
table_2 = pd.read_excel(r'data/EAG2014.xlsx',sheetname=None,skiprows=0)

# %%
table_2
# Out:
# {u'17-A':                                 Table-17: Level-wise Enrolment  Unnamed: 1  \
#  NaN                               A: All Categories of Students        NaN
#  NaN                                                         NaN        NaN
#  Level/\nYear  Primary                                       ...        NaN
#  NaN                                                        Boys      Girls
#  1950-51                                                     138         54
#  1960-61                                                     236        114
#  NaN                                                         NaN        NaN
#  NaN                                                         NaN        NaN
#  NaN                                                         NaN        NaN
#  1970-71                                                     357        213
#  1980-81                                                     453        285
# ...
